# %% [markdown]
# # hello

# %%
import sympy as sp
print(sp.__version__)
a = {'hello':1, 'world':2}
# Out:
# 1.4

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 100, 100)
y = np.sqrt(x)
plt.plot(x, y)
plt.show()
